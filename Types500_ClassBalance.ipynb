# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Types 500.csv')

# %%
sns.countplot(df.type)
# Out:
# /home/terist/.pyenv/versions/lewagon/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
df['e_i'] = df['type'].astype(str).str[0]
df['s_n'] = df['type'].astype(str).str[1]
df['f_t'] = df['type'].astype(str).str[2]
df['p_j'] = df['type'].astype(str).str[3]

# %%
df
# Out:
#                                                     posts  type e_i s_n f_t  \
# 0       know intj tool use interaction people excuse a...  INTJ   I   N   T
# 1       rap music ehh opp yeah know valid well know fa...  INTJ   I   N   T
# 2       preferably p hd low except wew lad video p min...  INTJ   I   N   T
# 3       drink like wish could drink red wine give head...  INTJ   I   N   T
# 4       space program ah bad deal meing freelance max ...  INTJ   I   N   T
# ...                                                   ...   ...  ..  ..  ..
# 106062  stay frustrate world life want take long nap w...  INFP   I   N   F
# 106063  fizzle around time mention sure mistake thing ...  INFP   I   N   F
# 106064  schedule modify hey w intp strong wing underst...  INFP   I   N   F
# 106065  enfj since january busy schedule able spend li...  INFP   I   N   F
# 106066  feel like men good problem tell parent want te...  INFP   I   N   F
#
#        p_j
# 0        J
# 1        J
# 2        J
# ...

# %%
sns.countplot(df.e_i)
# Out:
# /home/terist/.pyenv/versions/lewagon/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='e_i', ylabel='count'>

# %%
sns.countplot(df.s_n)
# Out:
# /home/terist/.pyenv/versions/lewagon/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='s_n', ylabel='count'>

# %%
sns.countplot(df.f_t)
# Out:
# /home/terist/.pyenv/versions/lewagon/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='f_t', ylabel='count'>

# %%
sns.countplot(df.p_j)
# Out:
# /home/terist/.pyenv/versions/lewagon/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='p_j', ylabel='count'>
